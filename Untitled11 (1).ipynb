# %%
# ============================================================
# Handwritten Digit Classification using TensorFlow
# Intern: GOUTHAM A M
# ============================================================

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# ------------------------------------------------------------
# 1. Load and Preprocess Dataset
# ------------------------------------------------------------

print("Loading MNIST Dataset...")

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Normalize pixel values (0–255 → 0–1)
x_train = x_train / 255.0
x_test = x_test / 255.0

print("Dataset Loaded Successfully")
print("Training Data Shape:", x_train.shape)

# ------------------------------------------------------------
# 2. Build Neural Network Model
# ------------------------------------------------------------

model = keras.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# ------------------------------------------------------------
# 3. Compile Model
# ------------------------------------------------------------

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Model Compiled Successfully")

# ------------------------------------------------------------
# 4. Train Model (with Validation Split)
# ------------------------------------------------------------

history = model.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=0.2
)

# ------------------------------------------------------------
# 5. Evaluate Model on Test Data
# ------------------------------------------------------------

test_loss, test_accuracy = model.evaluate(x_test, y_test)

print("\nFinal Test Accuracy:", test_accuracy)
print("Final Test Loss:", test_loss)

# ------------------------------------------------------------
# 6. Generate Predictions
# ------------------------------------------------------------

predictions = model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)

# ------------------------------------------------------------
# 7. Confusion Matrix
# ------------------------------------------------------------

cm = confusion_matrix(y_test, predicted_labels)

plt.figure()
sns.heatmap(cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# ------------------------------------------------------------
# 8. Accuracy Graph
# ------------------------------------------------------------

plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'])
plt.show()

# ------------------------------------------------------------
# 9. Save Final Model
# ------------------------------------------------------------

model.save("mnist_final_model.h5")
print("\nModel saved successfully as mnist_final_model.h5")

print("\nProject Completed Successfully.")
# Out:
# Loading MNIST Dataset...
# Dataset Loaded Successfully
# Training Data Shape: (60000, 28, 28)
# C:\Users\DELL\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model Compiled Successfully
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.8582 - loss: 0.4704 - val_accuracy: 0.9574 - val_loss: 0.1366
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9572 - loss: 0.1406 - val_accuracy: 0.9677 - val_loss: 0.1045
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9667 - loss: 0.1038 - val_accuracy: 0.9735 - val_loss: 0.0946
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9739 - loss: 0.0833 - val_accuracy: 0.9736 - val_loss: 0.0885
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9757 - loss: 0.0722 - val_accuracy: 0.9763 - val_loss: 0.0836
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9807 - loss: 0.0613 - val_accuracy: 0.9761 - val_loss: 0.0860
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9814 - loss: 0.0574 - val_accuracy: 0.9781 - val_loss: 0.0766
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9844 - loss: 0.0494 - val_accuracy: 0.9770 - val_loss: 0.0801
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9852 - loss: 0.0473 - val_accuracy: 0.9753 - val_loss: 0.0914
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9849 - loss: 0.0455 - val_accuracy: 0.9776 - val_loss: 0.0860
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9737 - loss: 0.0975
#
# Final Test Accuracy: 0.9793000221252441
# Final Test Loss: 0.0764567032456398
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully as mnist_final_model.h5
#
# Project Completed Successfully.
